# %%
import matplotlib.pyplot as plt

X = [0,1,2,3]
Y = [0,1,0,1]
plt.plot(X, Y)

# %%
import matplotlib.pyplot as plt

X = [0,1,2,3,4,5,6,7]
Y = [0,1,1,0,0,1,1,0]
plt.plot(X, Y)

# %%
import plotly.graph_objects as go

salaries = [
	("Mark", 1000),
	("John", 1500),
	("Daniel", 2300),
	("Greg", 5000)
]
names = list(map(lambda tup:tup[0], salaries))
salary_values = list(map(lambda tup:tup[1], salaries))

plt.plot(salary_values)

# %%
import plotly.graph_objects as go

salaries = [
	("Mark", 1000),
	("John", 1500),
	("Daniel", 2300),
	("Greg", 5000)
]
names = list(map(lambda tup:tup[0], salaries))
salary_values = list(map(lambda tup:tup[1], salaries))

plt.bar(names, salary_values)
# Out:
# <BarContainer object of 4 artists>

# %%
import plotly.graph_objects as go

salaries = [
	("Mark", 1000),
	("John", 1500),
	("Daniel", 2300),
	("Greg", 5000)
]
names = list(map(lambda tup:tup[0], salaries))
salary_values = list(map(lambda tup:tup[1], salaries))
                     
plt.title("Salaries")
plt.xlabel("Employee")
plt.ylabel("Salary in zł")
plt.bar(names, salary_values)
# Out:
# <BarContainer object of 4 artists>

# %%
import plotly.graph_objects as go

salaries = [
	("Mark", 1000),
	("John", 1500),
	("Daniel", 2300),
	("Greg", 5000)
]
names = list(map(lambda tup:tup[0], salaries))
salary_values = list(map(lambda tup:tup[1], salaries))
                     
figure, ax = plt.subplots()
ax.bar(names, salary_values)
ax.set_xlabel("Employee")
ax.set_ylabel("Salary in zł")
plt.bar(names, salary_values)
# Out:
# <BarContainer object of 4 artists>

# %%
import plotly.graph_objects as go

salaries = [
	("Mark", 1000),
	("John", 1500),
	("Daniel", 2300),
	("Greg", 5000)
]
names = list(map(lambda tup:tup[0], salaries))
salary_values = list(map(lambda tup:tup[1], salaries))
                     
figure, ax = plt.subplots()
ax.bar(names, salary_values)
ax.set_xlabel("Employee")
ax.set_ylabel("Salary in zł")
ax.invert_yaxis() #Label read top-to-bottom
plt.bar(names, salary_values)
# Out:
# <BarContainer object of 4 artists>

# %%
import plotly.graph_objects as go

salaries = [
	("Mark", 1000),
	("John", 1500),
	("Daniel", 2300),
	("Greg", 5000)
]
names = list(map(lambda tup:tup[0], salaries))
salary_values = list(map(lambda tup:tup[1], salaries))
                     
figure, ax = plt.subplots()
ax.barh(names, salary_values) # barh make horizontal bar
ax.set_ylabel("Employee")
ax.set_xlabel("Salary in zł")
plt.show()

# %%
import plotly.graph_objects as go

salaries = [
	("Mark", 1000),
	("John", 1500),
	("Daniel", 2300),
	("Greg", 5000)
]
names = list(map(lambda tup:tup[0], salaries))
salary_values = list(map(lambda tup:tup[1], salaries))
                     
figure, ax = plt.subplots()
ax.barh(names, salary_values, color='green') # barh make horizontal bar #add color
ax.set_ylabel("Employee")
ax.set_xlabel("Salary in zł")
plt.show()
